# %% [markdown]
# # 02 — GI Validation
#
# Sanity checks and diagnostics for the non-weighted and AHP-weighted Gravitational Index computed in `src/01_gi_construction.py`.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))
from config import DATA_PROCESSED
