# %% [markdown]
# # 01 — Data Exploration
#
# Exploratory look at the raw indicator, road network, and settlement datasets in `DATA_RAW`.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))
from config import DATA_RAW
